# %%
from obspy import read, read_inventory  

# Read waveform file
fl_name = "./archive/2026/GO/AZNN/HHZ.D/GO.AZNN.00.HHZ.D.2026.054"
st = read(fl_name)

# Preview metadata
print(st[0].stats)
print("___________________")
# Out:
#          network: GO
#          station: AZNN
#         location: 00
#          channel: HHZ
#        starttime: 2026-02-23T08:27:04.070000Z
#          endtime: 2026-02-23T08:32:41.900000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 33784
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 82, 'encoding': 'STEIM1', 'byteorder': '>', 'record_length': 512, 'filesize': 41984})
# ___________________

# %%
#   scevtstreams -E ies2026duod -d mysql://sysop:sysop@192.168.11.250/seiscomp -m 120,180 -R --all-stations | scart --list - -I fdsnws://192.168.11.250:8080 ./archive

# %%
# scevtstreams -E ies2026duod -d mysql://sysop:sysop@192.168.11.250/seiscomp -m 300 -R --all-stations > st.xml
